# %% [markdown]
# ## Getting your environment set up
#
# ### Importing Necessary Libraries

# %%
# Modules we will use
import pandas as pd
import numpy as np

# For Box-Cox transformation
from scipy import stats

# For min_max scaling
from mlxtend.preprocessing import minmax_scaling

# Visualization and plotting modules
import seaborn as sns
import matplotlib.pyplot as plt

# Setting the seed for reproducibility
np.random.seed(0)

# %% [markdown]
# # Scaling versus Normalization
#
# Scaling and Normalization are two approaches for transforming numerical values to have meaningful impact in a dataset. The main difference between them is that:
#    * In scaling, you are changing the range of the dataset, while
#    * In normalization, you are changing the size of the distribution of the dataset

# %% [markdown]
# ## Scaling
#
# This means that you're transforming your data so that it fits within a specific scale, like 0-100 or 0-1. You want to scale data when you're using methods based on measures of how far apart data points are, like support vector machines (SVM) or k-nearest neighbors (KNN). With these algorithms, a change of "1" in any numeric feature is given the same importance.
#
# By scaling your variables, you can help compare different variables on equal footing.

# %%
# generating 1000 data points randomly from the exponential distribution
original_data = np.random.exponential(size = 1000)
 
# using min-max scaling to scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns = [0])

# plotting both to compare
fig, ax = plt.subplots(1, 2, figsize = (15,3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled Data")
plt.show()

# %% [markdown]
# Notice that the shape of the data doesn't change, but that instead of ranging from 0 to 8, it now ranges from 0 to 1.

# %% [markdown]
# ## Normalization
#
# When we have a data that is skewed, it is advisable to normalize the data in order to make more accurate analysis. Normalization simply means, transforming the data so that it becomes a normal distribution.
# * In Statistics, a normal distribution is a distribution in which there are equal number of observations above the mean and below the mean. In normal distribution, the mean = median = mode. The normal distribution is also called the Gaussian distribution.
# In general, you'll normalize your data if you're going to be using a machine learning or statistics technique that assumes your data is normally distributed. Some examples of these include linear discriminant analysis (LDA) and Gaussian naive Bayes. (Pro tip: any method with "Gaussian" in the name probably assumes normality.)
#
# The method we're using to normalize here is called the Box-Cox Transformation. Let's take a quick peek at what normalizing some data looks like:

# %%
# normalizing the exponential data with boxcox
normalized_data = stats.boxcox(original_data)

# plotting the orginal data and normalized data to compare
fig, ax =plt.subplots(1, 2, figsize=(15,3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(normalized_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Normalized Data")
plt.show()

# %% [markdown]
# Notice that the shape of our data has changed. Before normalizing it was almost L-shaped. But after normalizing it looks more like the outline of a bell (hence "bell curve").
